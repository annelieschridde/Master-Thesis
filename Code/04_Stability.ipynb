# %% [markdown]
# # Stability Investigation - Bootstrapping

# %%
# %run my_functions.py
import plotly.express as px
# Out:
# C:\Users\Annelie Schridde\AppData\Roaming\Python\Python38\site-packages\spacy\util.py:865: UserWarning: [W095] Model 'en_core_web_sm' (3.0.0) was trained with spaCy v3.0 and may not be 100% compatible with the current version (3.4.0). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# [nltk_data] Downloading package stopwords to C:\Users\Annelie
# [nltk_data]     Schridde\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to C:\Users\Annelie
# [nltk_data]     Schridde\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Annelie
# [nltk_data]     Schridde\AppData\Roaming\nltk_data...
# ...

# %%
# loading preprocessed dataset
with open("../dataframes/raw_data_Books_00_clean_and_cut.pkl", "rb") as f:
    df = pickle.load(f)
df = df[:20000]

# %% [markdown]
# ## LSA

# %% [markdown]
# ### LSA TF

# %%
n_components =[2,4,6,8,10,15,20,25,30,35,40,45,50]
num_runs = 100

results_parallel = [parallel_npmi(df.cut_and_clean, "LSA",  k, B, False, 20) for B in trange(num_runs) for k in n_components]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
result = {}
for i in trange(len(results_parallel)):
    lst = list(results_parallel[i])
    if str(lst[0][0]) + " c_v" not in result.keys() or str(lst[0][0]) + " c_umass" not in result.keys() or str(lst[0][0]) + " c_npmi" not in result.keys() or str(lst[0][0]) + " c_uci" not in result.keys():
        result[str(lst[0][0]) + " c_v"] = []
        result[str(lst[0][0]) + " c_umass"] = []
        result[str(lst[0][0]) + " c_npmi"] = []
        result[str(lst[0][0]) + " c_uci"] = []
        
    result[str(lst[0][0]) + " c_v"].append(lst[0][1])
    result[str(lst[0][0]) + " c_umass"].append(lst[0][2])
    result[str(lst[0][0]) + " c_npmi"].append(lst[0][3])
    result[str(lst[0][0]) + " c_uci"].append(lst[0][4])

lsa_tf_stability = result
# Out:
#   0%|          | 0/1300 [00:00<?, ?it/s]
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# ...

# %%
lsa_tf = pd.DataFrame(lsa_tf_stability)

# %% [markdown]
# #### Visualizations LSA TF

# %%
with open("../Stability/lsa_tf_stability.pkl", "rb") as f:
    lsa_tf = pickle.load(f)

# %%
values_cv = []
values_umass = []
values_npmi = []
values_uci = []

for name in lsa_tf.columns:
    if " c_v" in name:
        values_cv.append(name)
    if " c_umass" in name:
        values_umass.append(name)
    if " c_npmi" in name:
        values_npmi.append(name)
    if " c_uci" in name:
        values_uci.append(name)

# %%
d_cv = {}
for col in values_cv:
    d_cv[col]=list(lsa_tf[col])

# %%
d_umass = {}
for col in values_umass:
    d_umass[col]=list(lsa_tf[col])

# %%
d_npmi = {}
for col in values_npmi:
    d_npmi[col]=list(lsa_tf[col])

# %%
d_uci = {}
for col in values_uci:
    d_uci[col]=list(lsa_tf[col])

# %%
visualize(path="lsa_tf_var.xlsx", Title_box="LSA with TF - Stability Analysis", Title_hist="LSA with TF - Distribution of Best Number of Topics according to Coherence Measures", d_cv = d_cv, d_umass= d_umass, d_uci = d_uci, d_npmi = d_npmi)

# %% [markdown]
# ### LSA TF-IDF

# %%
n_components = [2,4,6,8,10,15,20,25,30,35,40,45,50]
num_runs = 100

results_parallel = [parallel_npmi(df.cut_and_clean, "LSA",  k, B, True, 20) for B in trange(num_runs) for k in n_components]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
result = {}
for i in trange(len(results_parallel)):
    lst = list(results_parallel[i])
    if str(lst[0][0]) + " c_v" not in result.keys() or str(lst[0][0]) + " c_umass" not in result.keys() or str(lst[0][0]) + " c_npmi" not in result.keys() or str(lst[0][0]) + " c_uci" not in result.keys():
        result[str(lst[0][0]) + " c_v"] = []
        result[str(lst[0][0]) + " c_umass"] = []
        result[str(lst[0][0]) + " c_npmi"] = []
        result[str(lst[0][0]) + " c_uci"] = []
        
    result[str(lst[0][0]) + " c_v"].append(lst[0][1])
    result[str(lst[0][0]) + " c_umass"].append(lst[0][2])
    result[str(lst[0][0]) + " c_npmi"].append(lst[0][3])
    result[str(lst[0][0]) + " c_uci"].append(lst[0][4])
# Out:
#   0%|          | 0/1300 [00:00<?, ?it/s]
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# Running LSA...
# Task finished!
# ...

# %%
lsa_tfidf_stability = result
lsa_tfidf = pd.DataFrame(lsa_tfidf_stability)

# %% [markdown]
# #### Visualizations LSA TF-IDF

# %%
with open("../Stability/lsa_tfidf_stability.pkl", "rb") as f:
    lsa_tfidf = pickle.load(f)

# %%
values_cv = []
values_umass = []
values_npmi = []
values_uci = []

for name in lsa_tfidf.columns:
    if " c_v" in name:
        values_cv.append(name)
    if " c_umass" in name:
        values_umass.append(name)
    if " c_npmi" in name:
        values_npmi.append(name)
    if " c_uci" in name:
        values_uci.append(name)

d_cv = {}
for col in values_cv:
    d_cv[col]=list(lsa_tfidf[col])
d_umass = {}
for col in values_umass:
    d_umass[col]=list(lsa_tfidf[col])
d_npmi = {}
for col in values_npmi:
    d_npmi[col]=list(lsa_tfidf[col])
d_uci = {}
for col in values_uci:
    d_uci[col]=list(lsa_tfidf[col])
pd.DataFrame(d_cv)
# Out:
#        2 c_v     4 c_v     6 c_v     8 c_v    10 c_v    15 c_v    20 c_v  \
# 0   0.175267  0.220748  0.250577  0.234913  0.246981  0.251724  0.265059
# 1   0.216400  0.221779  0.250023  0.255294  0.263296  0.262801  0.270173
# 2   0.206509  0.252776  0.256141  0.254042  0.264165  0.265812  0.269570
# 3   0.303048  0.279527  0.308663  0.292709  0.287284  0.283832  0.280891
# 4   0.188723  0.239306  0.231552  0.256997  0.255827  0.278305  0.284820
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.230235  0.233334  0.233102  0.263360  0.271146  0.283342  0.285219
# 96  0.193081  0.219250  0.244299  0.255073  0.263646  0.264929  0.256458
# 97  0.308704  0.322424  0.331928  0.313647  0.297846  0.279743  0.278264
# 98  0.174286  0.245174  0.237441  0.230183  0.234643  0.251922  0.262902
# 99  0.173492  0.252094  0.284608  0.280423  0.284732  0.279813  0.274216
#
#       25 c_v    30 c_v    35 c_v    40 c_v    45 c_v    50 c_v
# ...

# %%
visualize(path= "lsa_tfidf_var.xlsx", Title_box="LSA with TF-IDF - Stability Analysis", Title_hist="LSA with TF-IDF - Distribution of Best Number of Topics according to Coherence Measures",d_cv=d_cv, d_uci=d_uci, d_npmi=d_npmi, d_umass=d_umass)

# %% [markdown]
# ## LDA

# %% [markdown]
# ### LDA TF

# %%
n_components = [2,4,6,8,10,15,20,25,30,35,40,45,50]
num_runs = 100

results_parallel = [parallel_npmi(df.cut_and_clean, "LDA",  k, B, False, 20) for B in trange(num_runs) for k in n_components]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
result = {}
for i in trange(len(results_parallel)):
    lst = list(results_parallel[i])
    if str(lst[0][0]) + " c_v" not in result.keys() or str(lst[0][0]) + " c_umass" not in result.keys() or str(lst[0][0]) + " c_npmi" not in result.keys() or str(lst[0][0]) + " c_uci" not in result.keys():
        result[str(lst[0][0]) + " c_v"] = []
        result[str(lst[0][0]) + " c_umass"] = []
        result[str(lst[0][0]) + " c_npmi"] = []
        result[str(lst[0][0]) + " c_uci"] = []
        
    result[str(lst[0][0]) + " c_v"].append(lst[0][1])
    result[str(lst[0][0]) + " c_umass"].append(lst[0][2])
    result[str(lst[0][0]) + " c_npmi"].append(lst[0][3])
    result[str(lst[0][0]) + " c_uci"].append(lst[0][4])

lsa_tf_stability = result
# Out:
#   0%|          | 0/1300 [00:00<?, ?it/s]
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# ...

# %%
lda_tf_stability = result
lda_tf = pd.DataFrame(lda_tf_stability)

# %% [markdown]
# #### Visualizations LDA TF

# %%
with open("../Stability/lda_tf_stability.pkl", "rb") as f:
    lda_tf = pickle.load(f)

# %%
with open("../Stability/lda_tf_stability.pkl", "rb") as f:
    lda_tf = pickle.load(f)

values_cv = []
values_umass = []
values_npmi = []
values_uci = []

for name in lda_tf.columns:
    if " c_v" in name:
        values_cv.append(name)
    if " c_umass" in name:
        values_umass.append(name)
    if " c_npmi" in name:
        values_npmi.append(name)
    if " c_uci" in name:
        values_uci.append(name)

d_cv = {}
for col in values_cv:
    d_cv[col]=list(lda_tf[col])
d_umass = {}
for col in values_umass:
    d_umass[col]=list(lda_tf[col])
d_npmi = {}
for col in values_npmi:
    d_npmi[col]=list(lda_tf[col])
d_uci = {}
for col in values_uci:
    d_uci[col]=list(lda_tf[col])
pd.DataFrame(d_cv)
# Out:
#        2 c_v     4 c_v     6 c_v     8 c_v    10 c_v    15 c_v    20 c_v  \
# 0   0.334872  0.363082  0.398742  0.388443  0.409153  0.432684  0.437327
# 1   0.391457  0.397653  0.387582  0.394489  0.399439  0.431978  0.419048
# 2   0.332425  0.377275  0.426246  0.424949  0.429810  0.464895  0.427431
# 3   0.408802  0.403212  0.424937  0.473316  0.485086  0.502648  0.508600
# 4   0.328899  0.404953  0.451580  0.451923  0.500562  0.485242  0.467286
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.386386  0.400478  0.454786  0.415533  0.431341  0.426026  0.415635
# 96  0.358496  0.455489  0.434798  0.381388  0.408280  0.446563  0.432542
# 97  0.312005  0.388827  0.437931  0.430501  0.445228  0.442610  0.452508
# 98  0.308624  0.367695  0.380044  0.386765  0.397156  0.405782  0.415000
# 99  0.374430  0.429371  0.438010  0.462215  0.513202  0.520687  0.506571
#
#       25 c_v    30 c_v    35 c_v    40 c_v    45 c_v    50 c_v
# ...

# %%
visualize(path= "lda_tf_var.xlsx", Title_box="LDA with TF - Stability Analysis", Title_hist="LDA with TF - Distribution of Best Number of Topics according to Coherence Measures",d_cv=d_cv, d_uci=d_uci, d_npmi=d_npmi, d_umass=d_umass)

# %% [markdown]
# ### LDA TF-IDF

# %%
n_components = [2,4,6,8,10,15,20,25,30,35,40,45,50]
num_runs = 100

results_parallel = [parallel_npmi(df.cut_and_clean, "LDA",  k, B, True, 20) for B in trange(num_runs) for k in n_components]
# Out:
#   0%|          | 0/100 [00:01<?, ?it/s]

# %%
result = {}
for i in trange(len(results_parallel)):
    lst = list(results_parallel[i])
    if str(lst[0][0]) + " c_v" not in result.keys() or str(lst[0][0]) + " c_umass" not in result.keys() or str(lst[0][0]) + " c_npmi" not in result.keys() or str(lst[0][0]) + " c_uci" not in result.keys():
        result[str(lst[0][0]) + " c_v"] = []
        result[str(lst[0][0]) + " c_umass"] = []
        result[str(lst[0][0]) + " c_npmi"] = []
        result[str(lst[0][0]) + " c_uci"] = []
        
    result[str(lst[0][0]) + " c_v"].append(lst[0][1])
    result[str(lst[0][0]) + " c_umass"].append(lst[0][2])
    result[str(lst[0][0]) + " c_npmi"].append(lst[0][3])
    result[str(lst[0][0]) + " c_uci"].append(lst[0][4])

lda_tfidf_stability = result
# Out:
#   0%|          | 0/1300 [00:00<?, ?it/s]
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# Running LDA...
# Task finished!
# ...

# %%
lda_tfidf = pd.DataFrame(lda_tfidf_stability)

# %% [markdown]
# #### Visualizations LDA TF-IDF

# %%
with open("../Stability/lda_tfidf_stability.pkl", "rb") as f:
    lda_tfidf = pickle.load(f)

# %%
with open("../Stability/lda_tfidf_stability.pkl", "rb") as f:
    lda_tfidf = pickle.load(f)
    
values_cv = []
values_umass = []
values_npmi = []
values_uci = []

for name in lda_tfidf.columns:
    if " c_v" in name:
        values_cv.append(name)
    if " c_umass" in name:
        values_umass.append(name)
    if " c_npmi" in name:
        values_npmi.append(name)
    if " c_uci" in name:
        values_uci.append(name)

d_cv = {}
for col in values_cv:
    d_cv[col]=list(lda_tfidf[col])
d_umass = {}
for col in values_umass:
    d_umass[col]=list(lda_tfidf[col])
d_npmi = {}
for col in values_npmi:
    d_npmi[col]=list(lda_tfidf[col])
d_uci = {}
for col in values_uci:
    d_uci[col]=list(lda_tfidf[col])
pd.DataFrame(d_cv)
# Out:
#        2 c_v     4 c_v     6 c_v     8 c_v    10 c_v    15 c_v    20 c_v  \
# 0   0.194009  0.222683  0.222553  0.227784  0.258369  0.305105  0.321843
# 1   0.200072  0.250280  0.223480  0.235550  0.248982  0.298735  0.308083
# 2   0.182641  0.244214  0.233155  0.240749  0.253731  0.270239  0.330361
# 3   0.261513  0.255270  0.241406  0.272351  0.287346  0.322861  0.337235
# 4   0.181188  0.173232  0.187795  0.229588  0.264327  0.296212  0.331950
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.222538  0.221965  0.223703  0.250837  0.271533  0.269529  0.293883
# 96  0.185992  0.215583  0.231998  0.201785  0.231157  0.285715  0.290790
# 97  0.201566  0.247373  0.246378  0.247422  0.243339  0.307856  0.330553
# 98  0.242963  0.160323  0.165948  0.210882  0.223806  0.268573  0.312957
# 99  0.233804  0.238355  0.211115  0.234550  0.250522  0.284330  0.300370
#
#       25 c_v    30 c_v    35 c_v    40 c_v    45 c_v    50 c_v
# ...

# %%
visualize(path= "lda_tfidf_var.xlsx", Title_box="LDA with TF-IDF - Stability Analysis", Title_hist="LDA with TF-IDF - Distribution of Best Number of Topics according to Coherence Measures",d_cv=d_cv, d_uci=d_uci, d_npmi=d_npmi, d_umass=d_umass)

# %% [markdown]
# ## NMF

# %% [markdown]
# ### NMF TF

# %%
n_components = [2,4,6,8,10,15,20,25,30,35,40,45,50]
num_runs = 100

results_parallel = [parallel_npmi(df.cut_and_clean, "NMF",  k, B, False, 20) for B in trange(num_runs) for k in n_components]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
result = {}
for i in trange(len(results_parallel)):
    lst = list(results_parallel[i])
    if str(lst[0][0]) + " c_v" not in result.keys() or str(lst[0][0]) + " c_umass" not in result.keys() or str(lst[0][0]) + " c_npmi" not in result.keys() or str(lst[0][0]) + " c_uci" not in result.keys():
        result[str(lst[0][0]) + " c_v"] = []
        result[str(lst[0][0]) + " c_umass"] = []
        result[str(lst[0][0]) + " c_npmi"] = []
        result[str(lst[0][0]) + " c_uci"] = []
        
    result[str(lst[0][0]) + " c_v"].append(lst[0][1])
    result[str(lst[0][0]) + " c_umass"].append(lst[0][2])
    result[str(lst[0][0]) + " c_npmi"].append(lst[0][3])
    result[str(lst[0][0]) + " c_uci"].append(lst[0][4])
# Out:
#   0%|          | 0/1300 [00:00<?, ?it/s]
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# C:\Users\Annelie Schridde\AppData\Roaming\Python\Python38\site-packages\sklearn\decomposition\_nmf.py:1692: ConvergenceWarning:
#
# Maximum number of iterations 200 reached. Increase it to improve convergence.
# Task finished!
# Running NMF...
# C:\Users\Annelie Schridde\AppData\Roaming\Python\Python38\site-packages\sklearn\decomposition\_nmf.py:1692: ConvergenceWarning:
#
# Maximum number of iterations 200 reached. Increase it to improve convergence.
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# C:\Users\Annelie Schridde\AppData\Roaming\Python\Python38\site-packages\sklearn\decomposition\_nmf.py:1692: ConvergenceWarning:
#
# ...

# %%
nmf_tf_stability = result
nmf_tf = pd.DataFrame(nmf_tf_stability)

# %% [markdown]
# #### Visualizations NMF TF

# %%
with open("../Stability/nmf_tf_stability.pkl", "rb") as f:
    nmf_tf = pickle.load(f)

# %%
with open("../Stability/nmf_tf_stability.pkl", "rb") as f:
    nmf_tf = pickle.load(f)

values_cv = []
values_umass = []
values_npmi = []
values_uci = []

for name in nmf_tf.columns:
    if " c_v" in name:
        values_cv.append(name)
    if " c_umass" in name:
        values_umass.append(name)
    if " c_npmi" in name:
        values_npmi.append(name)
    if " c_uci" in name:
        values_uci.append(name)

d_cv = {}
for col in values_cv:
    d_cv[col]=list(nmf_tf[col])
d_umass = {}
for col in values_umass:
    d_umass[col]=list(nmf_tf[col])
d_npmi = {}
for col in values_npmi:
    d_npmi[col]=list(nmf_tf[col])
d_uci = {}
for col in values_uci:
    d_uci[col]=list(nmf_tf[col])
pd.DataFrame(d_uci)
# Out:
#      2 c_uci   4 c_uci   6 c_uci   8 c_uci  10 c_uci  15 c_uci  20 c_uci  \
# 0  -0.107638 -1.403389 -0.914488 -1.143970 -0.965724 -0.878501 -0.951279
# 1  -3.138152 -2.451832 -1.728398 -1.643166 -1.359291 -1.519585 -1.720076
# 2   0.038172 -0.734881 -0.580139 -0.766706 -0.474960 -0.526175 -0.926856
# 3  -0.172980 -0.799285 -0.852068 -0.470374 -0.648306 -0.663588 -0.871940
# 4  -1.341134 -0.792536 -0.526462 -0.383605 -0.737093 -1.187426 -1.880486
# ..       ...       ...       ...       ...       ...       ...       ...
# 95 -1.094090 -1.142707 -0.781961 -0.769589 -1.037988 -1.343783 -1.543089
# 96 -2.388783 -0.680769 -0.459946 -0.221131 -0.628682 -0.786336 -1.315002
# 97 -0.616847 -2.213617 -1.833003 -1.344636 -2.007194 -1.298382 -1.469813
# 98 -0.871882 -1.354655 -1.025759 -0.794895 -1.215638 -1.612366 -1.497539
# 99 -0.620240 -0.043799  0.057618 -0.178136 -0.432367 -1.120331 -1.654961
#
#     25 c_uci  30 c_uci  35 c_uci  40 c_uci  45 c_uci  50 c_uci
# ...

# %%
visualize(path= "NMF_tf_var.xlsx", Title_box="NMF with TF - Stability Analysis", Title_hist="NMF with TF - Distribution of Best Number of Topics according to Coherence Measures",d_cv=d_cv, d_uci=d_uci, d_npmi=d_npmi, d_umass=d_umass)

# %% [markdown]
# ### NMF TF-iDF

# %%
n_components = [2,4,6,8,10,15,20,25,30,35,40,45,50]
num_runs = 100

results_parallel = [parallel_npmi(df.cut_and_clean, "NMF",  k, B, True, 20) for B in trange(num_runs) for k in n_components]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
result = {}
for i in trange(len(results_parallel)):
    lst = list(results_parallel[i])
    if str(lst[0][0]) + " c_v" not in result.keys() or str(lst[0][0]) + " c_umass" not in result.keys() or str(lst[0][0]) + " c_npmi" not in result.keys() or str(lst[0][0]) + " c_uci" not in result.keys():
        result[str(lst[0][0]) + " c_v"] = []
        result[str(lst[0][0]) + " c_umass"] = []
        result[str(lst[0][0]) + " c_npmi"] = []
        result[str(lst[0][0]) + " c_uci"] = []
        
    result[str(lst[0][0]) + " c_v"].append(lst[0][1])
    result[str(lst[0][0]) + " c_umass"].append(lst[0][2])
    result[str(lst[0][0]) + " c_npmi"].append(lst[0][3])
    result[str(lst[0][0]) + " c_uci"].append(lst[0][4])

lsa_tf_stability = result
# Out:
#   0%|          | 0/1300 [00:00<?, ?it/s]
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# Task finished!
# Running NMF...
# C:\Users\Annelie Schridde\AppData\Roaming\Python\Python38\site-packages\sklearn\decomposition\_nmf.py:1692: ConvergenceWarning:
#
# ...

# %%
nmf_tfidf_stability = result
nmf_tfidf = pd.DataFrame(nmf_tfidf_stability)

# %% [markdown]
# #### Visualizations NMF TF-IDF

# %%
with open("../Stability/nmf_tfidf_stability.pkl", "rb") as f:
    nmf_tfidf = pickle.load(f)

# %%
with open("../Stability/nmf_tfidf_stability.pkl", "rb") as f:
    nmf_tfidf = pickle.load(f)
values_cv = []
values_umass = []
values_npmi = []
values_uci = []

for name in nmf_tfidf.columns:
    if " c_v" in name:
        values_cv.append(name)
    if " c_umass" in name:
        values_umass.append(name)
    if " c_npmi" in name:
        values_npmi.append(name)
    if " c_uci" in name:
        values_uci.append(name)

d_cv = {}
for col in values_cv:
    d_cv[col]=list(nmf_tfidf[col])
d_umass = {}
for col in values_umass:
    d_umass[col]=list(nmf_tfidf[col])
d_npmi = {}
for col in values_npmi:
    d_npmi[col]=list(nmf_tfidf[col])
d_uci = {}
for col in values_uci:
    d_uci[col]=list(nmf_tfidf[col])
pd.DataFrame(d_cv)
# Out:
#        2 c_v     4 c_v     6 c_v     8 c_v    10 c_v    15 c_v    20 c_v  \
# 0   0.239196  0.282667  0.284656  0.282369  0.298117  0.330035  0.340326
# 1   0.256530  0.313193  0.292068  0.281978  0.295129  0.317302  0.337385
# 2   0.248506  0.284919  0.312662  0.321614  0.319469  0.330840  0.339526
# 3   0.334835  0.308073  0.319092  0.320245  0.337702  0.333695  0.322771
# 4   0.280748  0.265811  0.320610  0.305434  0.331625  0.311190  0.307314
# ..       ...       ...       ...       ...       ...       ...       ...
# 95  0.306516  0.299439  0.312871  0.317869  0.330917  0.334990  0.339559
# 96  0.269221  0.292952  0.302903  0.327173  0.326499  0.307335  0.337269
# 97  0.239539  0.317779  0.331272  0.319887  0.333442  0.354270  0.359917
# 98  0.209205  0.316250  0.317461  0.311333  0.306300  0.325917  0.346153
# 99  0.259061  0.301768  0.350967  0.331017  0.352774  0.322745  0.327886
#
#       25 c_v    30 c_v    35 c_v    40 c_v    45 c_v    50 c_v
# ...

# %%
visualize(path= "NMF_tfidf_var.xlsx", Title_box="NMF with TF-IDF - Stability Analysis", Title_hist="NMF with TF-IDF - Distribution of Best Number of Topics according to Coherence Measures",d_cv=d_cv, d_uci=d_uci, d_npmi=d_npmi, d_umass=d_umass)

# %% [markdown]
# #### Medians and Variances (normalized)

# %% [markdown]
# * Combining metric values of each model to one data frame
# * Divide the concatenated data frame into the different metrics (cv, umass, npmi and uci)
# * Normalize each set of metrics
# * Calculate median and variance for each metric
# * Save data frames as tables in MS Excel

# %%
dfs = [lsa_tf,lsa_tfidf, lda_tf, lda_tfidf, nmf_tf, nmf_tfidf]

# %%
df_cv, df_umass, df_npmi, df_uci = prepare_sets(dfs)

# %%
names = ["2 Topics","4 Topics", "6 Topics", "8 Topics", "10 Topics", "15 Topics", "20 Topics", "25 Topics", "30 Topics", "35 Topics", "40 Topics", "45 Topics" , "50 Topics",
"2 Topics","4 Topics", "6 Topics", "8 Topics", "10 Topics", "15 Topics", "20 Topics", "25 Topics", "30 Topics", "35 Topics", "40 Topics", "45 Topics" , "50 Topics",
"2 Topics","4 Topics", "6 Topics", "8 Topics", "10 Topics", "15 Topics", "20 Topics", "25 Topics", "30 Topics", "35 Topics", "40 Topics", "45 Topics" , "50 Topics",
"2 Topics","4 Topics", "6 Topics", "8 Topics", "10 Topics", "15 Topics", "20 Topics", "25 Topics", "30 Topics", "35 Topics", "40 Topics", "45 Topics" , "50 Topics",
"2 Topics","4 Topics", "6 Topics", "8 Topics", "10 Topics", "15 Topics", "20 Topics", "25 Topics", "30 Topics", "35 Topics", "40 Topics", "45 Topics" , "50 Topics",
"2 Topics","4 Topics", "6 Topics", "8 Topics", "10 Topics", "15 Topics", "20 Topics", "25 Topics", "30 Topics", "35 Topics", "40 Topics", "45 Topics" , "50 Topics"]

# %%
df_cv.columns = names
df_umass.columns = names
df_npmi.columns = names
df_uci.columns = names

# %%
show_var("../Stability/variances_normed.xlsx", df_cv, df_umass, df_npmi, df_uci)
# Out:
# (     LSA TF  LSA TF-IDF   LDA TF  LDA TF-IDF   NMF TF  NMF TF-IDF
#  2   0.00053     0.00045  0.00012     0.00050  0.00044     0.00014
#  4   0.00036     0.00022  0.00009     0.00047  0.00026     0.00007
#  6   0.00020     0.00020  0.00006     0.00040  0.00019     0.00006
#  8   0.00013     0.00022  0.00006     0.00024  0.00016     0.00004
#  10  0.00010     0.00024  0.00007     0.00008  0.00014     0.00005
#  15  0.00006     0.00023  0.00007     0.00002  0.00012     0.00003
#  20  0.00005     0.00019  0.00007     0.00003  0.00010     0.00004
#  25  0.00004     0.00016  0.00007     0.00003  0.00009     0.00002
#  30  0.00003     0.00012  0.00006     0.00002  0.00008     0.00002
#  35  0.00002     0.00010  0.00005     0.00002  0.00008     0.00001
#  40  0.00002     0.00009  0.00005     0.00002  0.00008     0.00001
#  45  0.00002     0.00009  0.00005     0.00002  0.00008     0.00001
#  50  0.00002     0.00008  0.00004     0.00002  0.00008     0.00001,
# ...

# %%
show_median("median", df_cv, df_umass, df_npmi, df_uci)
# Out:
# (     LSA TF  LSA TF-IDF   LDA TF  LDA TF-IDF   NMF TF  NMF TF-IDF
#  2   0.13267     0.07570  0.10173     0.06623  0.13535     0.07932
#  4   0.14851     0.08051  0.11398     0.07080  0.15648     0.08842
#  6   0.14447     0.08330  0.12069     0.07200  0.16931     0.09470
#  8   0.14042     0.08235  0.12473     0.07317  0.16778     0.09335
#  10  0.13734     0.08234  0.12647     0.07514  0.16663     0.09407
#  15  0.12796     0.08180  0.12778     0.08260  0.16429     0.09552
#  20  0.12231     0.08164  0.12256     0.08780  0.15846     0.09558
#  25  0.11793     0.08229  0.11419     0.08757  0.15568     0.09431
#  30  0.11451     0.08258  0.11021     0.08811  0.15378     0.09251
#  35  0.11200     0.08314  0.11082     0.08813  0.14995     0.09220
#  40  0.11005     0.08321  0.11123     0.08751  0.14653     0.09240
#  45  0.10756     0.08342  0.11154     0.08715  0.14384     0.09217
#  50  0.10545     0.08257  0.11274     0.08792  0.14198     0.09191,
# ...
